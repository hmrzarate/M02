# %%
# Program Name: ZARATE_HEATHER_M02_programming_assignment
# Author: Heather Zarate
# Date: 9/5/2022


# 4.1 activity

secret = 6
guess = 4

if guess < secret:
    print("too low")

elif guess > secret:
    print("too high")

elif guess == secret:
    print("just right")


# Program name: 4.2 activity
# author: Heather Zarate
# date: 9/5/2022


# 4.2 activity 

green = True
small = False

if green:
    if small:
        print("Its a pea.")
    else:
        print("Its a watermelon.")
else:
    if small:
        print("It's a pumpkin.")
    else:
        print("It's a cherry.")
        

# Program name: 6.1 activity
# author: Heather Zarate
# date: 9/5/2022 

num_list = [3,2,1,0]

for num in num_list:
    print(num)

    
    
# Program name: 6.2 activity
# author: Heather Zarate
# date: 9/5/2022


guess_me = 7
number = 1

while number < guess_me:
    print("too low")
    number += 1
while number == guess_me:
    print("found it!")
    
    break

while number > guess_me:
    print("oops")
    
    break
    
    
    
# Program name: 6.3 activity
# author: Heather Zarate
# date: 9/5/2022

guess_me = 5

for number in range (10):

    if number < guess_me:
        print("too low")
        
    if number == guess_me:
        print("found it!")
        
        break
        
    if number > guess_me:
        print("oops")
        
        break
